# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных." data-toc-modified-id="Подготовка-данных.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных.</a></span><ul class="toc-item"><li><span><a href="#Открытие-файлов." data-toc-modified-id="Открытие-файлов.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Открытие файлов.</a></span><ul class="toc-item"><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Проверка,-что-эффективность-обогащения-рассчитана-правильно." data-toc-modified-id="Проверка,-что-эффективность-обогащения-рассчитана-правильно.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка, что эффективность обогащения рассчитана правильно.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проанализируйте-признаки,-недоступные-в-тестовой-выборке." data-toc-modified-id="Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проанализируйте признаки, недоступные в тестовой выборке.</a></span></li><li><span><a href="#Проведите-предобработку-данных." data-toc-modified-id="Проведите-предобработку-данных.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проведите предобработку данных.</a></span><ul class="toc-item"><li><span><a href="#Удаление-столбцов-из-обучающей-(train)-выборки." data-toc-modified-id="Удаление-столбцов-из-обучающей-(train)-выборки.-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Удаление столбцов из обучающей (train) выборки.</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных." data-toc-modified-id="Анализ-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных.</a></span><ul class="toc-item"><li><span><a href="#Анализ-концентрации-металлов-(Au,-Ag,-Pb)." data-toc-modified-id="Анализ-концентрации-металлов-(Au,-Ag,-Pb).-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ концентрации металлов (Au, Ag, Pb).</a></span><ul class="toc-item"><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Сравнение-распределений-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравнение-распределений-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравнение распределений размеров гранул сырья на обучающей и тестовой выборках.</a></span><ul class="toc-item"><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Исследование-суммарных-концентраций-веществ." data-toc-modified-id="Исследование-суммарных-концентраций-веществ.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарных концентраций веществ.</a></span><ul class="toc-item"><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li></ul></li><li><span><a href="#Финальная-подготовка-данных-для-построения-моделей." data-toc-modified-id="Финальная-подготовка-данных-для-построения-моделей.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Финальная подготовка данных для построения моделей.</a></span><ul class="toc-item"><li><span><a href="#Подготовка-выборок." data-toc-modified-id="Подготовка-выборок.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подготовка выборок.</a></span><ul class="toc-item"><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Функция-для-вычесления-итоговой-sMAPE." data-toc-modified-id="Функция-для-вычесления-итоговой-sMAPE.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция для вычесления итоговой sMAPE.</a></span></li></ul></li><li><span><a href="#Моделирование.-Получение-результатов." data-toc-modified-id="Моделирование.-Получение-результатов.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Моделирование. Получение результатов.</a></span><ul class="toc-item"><li><span><a href="#Бейзлайн-на-константной-модели." data-toc-modified-id="Бейзлайн-на-константной-модели.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Бейзлайн на константной модели.</a></span></li><li><span><a href="#Нахождение-лучшей-модели-по-критерию-sMAPE." data-toc-modified-id="Нахождение-лучшей-модели-по-критерию-sMAPE.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Нахождение лучшей модели по критерию sMAPE.</a></span><ul class="toc-item"><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Расчет-на-тестовой-выборке" data-toc-modified-id="Расчет-на-тестовой-выборке-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Расчет на тестовой выборке</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %%
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.simplefilter('ignore')
import plotly.express as px
from IPython.display import display #импортируем функцию display для лучшего вывода таблиц
import pandas as pd 
import numpy as np
import importlib #реализация оператора импорта Python
from collections import Counter

#Библиотека sklearn
from sklearn.model_selection import GridSearchCV, cross_val_score, cross_validate
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_error, make_scorer
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.dummy import DummyRegressor
from sklearn import tree

# %%
pd.options.display.float_format = '{:,.2f}'.format #хочу, чтобы данные типа float записывались с сепаратором и округлялись
pd.set_option('display.max_columns', 100) 
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 500)
verbose = True

# %% [markdown]
# # Подготовка данных.

# %% [markdown]
# ## Открытие файлов.

# %%
try:
    full = pd.read_csv(r'D:\Sborniy Project №2\data\gold_recovery_full.csv', sep = ',')
    test = pd.read_csv(r'D:\Sborniy Project №2\data\gold_recovery_test.csv', sep = ',')
    train = pd.read_csv(r'D:\Sborniy Project №2\data\gold_recovery_train.csv', sep = ',')
except:
    train = pd.read_csv('/datasets/gold_recovery_train.csv')
    test = pd.read_csv('/datasets/gold_recovery_test.csv')
    full = pd.read_csv('/datasets/gold_recovery_full.csv')

# %%
for i in [train, test, full]:
    print(i.shape)
# Out:
# (16860, 87)
# (5856, 53)
# (22716, 87)

# %%
for i in [train, test, full]:
    display(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16860 entries, 0 to 16859
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                16860 non-null  object
#  1   final.output.concentrate_ag                         16788 non-null  float64
#  2   final.output.concentrate_pb                         16788 non-null  float64
#  3   final.output.concentrate_sol                        16490 non-null  float64
#  4   final.output.concentrate_au                         16789 non-null  float64
#  5   final.output.recovery                               15339 non-null  float64
#  6   final.output.tail_ag                                16794 non-null  float64
#  7   final.output.tail_pb                                16677 non-null  float64
# ...

# %% [markdown]
# ### Вывод.

# %% [markdown]
# 1) Таким образом мы имеем 3 выборки: обучающую, тестовую и общую, содержащую данные по этим 2 выборкам.
# 2) В тестовой выборке меньше всего столбцов: 53 столбца.
# 3) В обучающей выборке 87 столбцов. Таким образом из обучающей выборки необходимо будет удалить 34 столбца, которые отсутвуют в тестовой выборке. В противном случае мы не можем построить проверяемую модель.
# 4) Так же наблюдается большое количетсво пропусков в обучающей выборке и как следствие в общей выборке.

# %% [markdown]
# ## Проверка, что эффективность обогащения рассчитана правильно.

# %% [markdown]
# Вычислим её на обучающей выборке для признака 'rougher.output.recovery'. Что означает: эффективность обогощения на выходе после процесса флотации. Согласно описанию технологического процесса: данный коэффицент будет состоять из следующих величин:
# C = rougher.output.concentrate_au
# F = 'rougher.input.feed_ag'
# T = rougher.output.tail_au.
# Изначально определим кол-во пропусков, в перечеслинных выше столбцах.

# %% [markdown]
# Выделем срез данных со значениями в столбце 'rougher.output.recovery' не равными NaN. Далее проверим кол-во пропусков в интересующих нас столбцах (выше приведен список из 4 столбцов) в полученном датафрейме.

# %%
print('Кол-во пропусков:')
train[~train['rougher.output.recovery'].isnull()][['rougher.output.recovery', 'rougher.output.concentrate_au', 
                     'rougher.input.feed_ag', 'rougher.output.tail_au']].isnull().sum()
# Out:
# Кол-во пропусков:
# rougher.output.recovery          0
# rougher.output.concentrate_au    0
# rougher.input.feed_ag            0
# rougher.output.tail_au           0
# dtype: int64

# %% [markdown]
# Для того, чтобы не создавать лишние глобальные переменные, произведем расчет через функцию.

# %%
def MAE_check(df):
    """
    Calculation, according task 1.2, MAE
    
    Input parameters:
    df - dataframe
    """
    data_slice = df[~df['rougher.output.recovery'].isnull()]
    C = data_slice['rougher.output.concentrate_au']
    F = data_slice['rougher.input.feed_au']
    T = data_slice['rougher.output.tail_au']
    data_slice['recovery_calculated'] = (C * (F - T)) / (F * (C - T)) * 100
    MAE = mean_absolute_error(data_slice['recovery_calculated'], data_slice['rougher.output.recovery'])
    return MAE

# %%
print(f"MAE состовляет: {MAE_check(train)}")
# Out:
# MAE состовляет: 9.444891926100695e-15

# %% [markdown]
# ### Вывод

# %% [markdown]
# **MAE Состовляет 9.444891926100695e-15. Расчет recovery в train выборке верный.**

# %% [markdown]
# ## Проанализируйте признаки, недоступные в тестовой выборке.

# %%
for i in [train, test, full]:
    print(i.shape)
# Out:
# (16860, 87)
# (5856, 53)
# (22716, 87)

# %% [markdown]
# Проанализируем столбцы из обучающей выборки, которые отсутсвуют в тестовой выборке.

# %%
[column for column in list(train.columns) if (column not in list(test.columns))]
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Столбцы, которые отсутвуют в тестовой выборке, можно разделить на следующие категории:
# 1) Финальные параметры продуктов на выходе: концентрации.
# 2) Финальные объемы хвостов.
# 3) Финальные параметры продуктов после первичной очистки: концентрации.
# 4) Финальные объемы хвостов после первичной очистки.
# 5) Объемы реагентов, участвовших в процессе флотации.
# 6) Параметры продуктов после флотации: концентрации.
# 7) Объемы хвостов после флотации.
# 8) Финальные характеристики продуктов после вторичной очистки.
#
# Так же необходимо заметить, что почти все признаки из 34, которые отсутвуют в тестовой выборке описывают параметры продукта (output). Возможно, на момент выгрузки данных, информации по данному параметру не было.

# %% [markdown]
# ## Проведите предобработку данных.

# %% [markdown]
# ### Удаление столбцов из обучающей (train) выборки.

# %% [markdown]
# Заполним значения nan в столбцах через метод fillna с аргументом ffill. В этом случае значения nan будут заполняться предыдущими значениями из этого же столбца, до тех пор пока в столбце не появится отличное от nan значение.

# %%
display(train.isnull().sum())
train = train.fillna(method='ffill')
display(train.isnull().sum())
# Out:
# date                                                     0
# final.output.concentrate_ag                             72
# final.output.concentrate_pb                             72
# final.output.concentrate_sol                           370
# final.output.concentrate_au                             71
# final.output.recovery                                 1521
# final.output.tail_ag                                    66
# final.output.tail_pb                                   183
# final.output.tail_sol                                  145
# final.output.tail_au                                    66
# primary_cleaner.input.sulfate                         1307
# primary_cleaner.input.depressant                      1262
# primary_cleaner.input.feed_size                          0
# primary_cleaner.input.xanthate                         985
# primary_cleaner.output.concentrate_ag                   82
# primary_cleaner.output.concentrate_pb                  358
# ...

# %% [markdown]
# # Анализ данных.

# %% [markdown]
# ## Анализ концентрации металлов (Au, Ag, Pb).

# %% [markdown]
# Нас интересуют следующие столбцы:
# 1) 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_au'
# 2) 'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_au'
# 4) 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_au'

# %% [markdown]
# Создадим датафрейм metall_concentration и будем использовать для дальнейшего анализа.

# %%
metall_concentration = full[[
'date', 
'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_au',
'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_au',         
'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_au'                     
                             ]]

# %% [markdown]
# Так как нам необходимо провести анализ изменения концентраций по времени то переведем столбец date в формат даты и времени.

# %%
metall_concentration['date'] = pd.to_datetime(metall_concentration['date'], format = '%Y-%m-%d %H:%M:%S')

# %% [markdown]
# Мы видим, что данные по времени записывались с шагом в один час. На данный момент у нас есть гипотеза, что данная частотность появления данных очень большая. Создадим дополнительный столбец, где будет округление данных до одного дня.

# %%
metall_concentration['date_rounded'] = metall_concentration['date'].dt.round('1D')

# %% [markdown]
# Проверим данные на количество пропусков.

# %%
metall_concentration.isnull().sum()
# Out:
# date                                       0
# rougher.output.concentrate_ag             98
# rougher.output.concentrate_pb             98
# rougher.output.concentrate_au             98
# primary_cleaner.output.concentrate_ag     98
# primary_cleaner.output.concentrate_pb    448
# primary_cleaner.output.concentrate_au     98
# final.output.concentrate_ag               89
# final.output.concentrate_pb               87
# final.output.concentrate_au               86
# date_rounded                               0
# dtype: int64

# %% [markdown]
# Пропусков не много и как можно увидеть, во многих столбцах кол-во пропусков одинаково, скорее всего в опредленныые даты и время запись не велась по тем или иным причинам. Удалим их.

# %%
metall_concentration.dropna(subset = [
'date', 
'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag',
'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb', 
'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au'                     
                             ], 
                               inplace = True)

# %% [markdown]
# Сгруппируем наши данные по столбца 'date_rounded'. В каждой строчке данного столбца будут средние значения за 1 час.

# %%
metall_concentration_grouped = metall_concentration.groupby('date_rounded')[[
'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag',
'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb', 
'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au']].mean()
print(f"Кол-во записей после группировки по столбцв 'date_rounded' в один день: {len(metall_concentration_grouped)}")
# Out:
# Кол-во записей после группировки по столбцв 'date_rounded' в один день: 946

# %%
def draw_timeline(df, element_of_the_periodic_table):
    """
    This function draws 2 graphs:
    1) Metall concentrations vs time for 3 different technological process
    2) Metall concentrations vs technological operation
    
    Input parameters:
    df - dataframe
    element_of_the_periodic_table - chemical element according to Periodic table. Abbreviation according to the table. 
    """
    dict_sample = dict({'au':'Золото', 'pb':'Свинец', 'ag':'Серебро'})
    
    column_names = []
    
    for column in metall_concentration_grouped.columns:
        if column.find(element_of_the_periodic_table) != -1:
            column_names.append(column)
    
    sns.set()
    f, axes = plt.subplots(1, 1, figsize=(20, 9))
    axes.set_title(dict_sample[element_of_the_periodic_table] + ': распределение концентрациии по времени', fontsize=18)
    axes.set_ylabel('Концентрация', fontsize=15)
    axes.set_xlabel('Распределение по дням', fontsize=15)
    sns.lineplot(data = df[column_names])
    
    sns.set()
    f, axes = plt.subplots(1, 1, figsize=(20, 9))
    axes.set_title(dict_sample[element_of_the_periodic_table] + ': медианы и распредления концентраций по технологическим операциям', fontsize=18)
    axes.set_ylabel('Медианы по технологическим операциям', fontsize=15)
    axes.set_xlabel('Технологические операции', fontsize=15)
    ax = sns.violinplot(data = df[column_names])

# %%
draw_timeline(metall_concentration_grouped, 'au')

# %%
draw_timeline(metall_concentration_grouped, 'pb')

# %%
draw_timeline(metall_concentration_grouped, 'ag')

# %% [markdown]
# По графикм мы видим, что у нас есть выбросы в показаниях. У нас есть хвосты в низу распределений. Дальше возможны 2 сценария удаления выбросов:
# 1) Определить по каждому из столбцов 1.5 межквартальных размаха и удалить выбросы.
# 2) По каждому из столбцов определить 1.5 межквартальных размаха и найти пересечения индексов данных столбцов и удалить данные индексы.
#
# Так же необходимо заметить, что если сделать срез данных по какому-либо однмоу металлу с параметром концентрации равным нулю на одном из технологичеких этапов (например: rougher.output.concentrate_ag), то можно заметить, что концентрации по остальным металлам так же будут равны нулю. Исходя из той информации, которая у нас есть неясно, является ли это артефактом или это нормально с точки зрения технологического процесса.
#
# Далее будем придерживаться стратегии номер 2:
# Определить по каждому из столбцов 1.5 межквартальных размаха и удалить выбросы.
#
# Так же, необходимо помнить, что для более качественного анализа необходимо понимать технологический процесс данного производства. Как пример, "нижние" хвосты в распределениях метталов, могут быть технологическими хвостами (tail). Т.е. мелкодисперсной фазой, котороая по тем или иным причинам не отделилась в категорию хвостов (tail).

# %% [markdown]
# Введем 2 функции:
# 1) Функция iqr, которая будет считать 1.5 квартальных разамах.
# 2) Фнкцция slice_preparation_wo_outliners, которая будет по каждому из столбцов датафрейма определять через функцию iqr интервалы выбросов и затем удалять эти значения. Размах интересующего нас интервала можно выбирать самостоятельно.

# %%
def iqr(df, column):
    """
    Function shows lower and upper bonds for the column
    
    Input parameters:
    df - dataframe
    column - column for calculations.
    """
    iqr = df[column].describe()[6] - df[column].describe()[4]
    low_bond = df[column].describe()[4] - 1.5 * iqr # считаем нижнюю границу
    if low_bond < 0: # бывает так, что нижняя граница уходит в минус, значит ей можно присвоить минимум признака 
        low_bond = df[column].describe()[3]
    upper_bond = df[column].describe()[6] + 1.5 * iqr # верхняя гранциа
    print('Нижняя граница:', low_bond)
    print('Верхняя граница:', upper_bond)

# %%
def slice_preparation_wo_outliners(df):
    """
    Function for calculation of iqr for each of the column in df
    Then, upper, lower bonds save in the array. Then the function takes these values from the array and make a slice of df, 
    based on this array.
    
    Input parameters:
    df - dataframe
    """
    final_array = []
    print(len(df))
    for column in df.columns[1:]:
        iqr = df[column].describe()[6] - df[column].describe()[4]
        low_bond = df[column].describe()[4] - 3.0 * iqr # считаем нижнюю границу 
        if low_bond < 0: # бывает так, что нижняя граница уходит в минус, значит ей можно присвоить минимум признака
            low_bond = df[column].describe()[3]
        upper_bond = df[column].describe()[6] + 3.0 * iqr # верхняя гранциа
        final_array.append([low_bond, upper_bond])
    for i in range(1, len(df.columns)):     
        df = df[(df.iloc[:, i] > final_array[i-1][0]) & (df.iloc[:,i] < final_array[i-1][1])] 
        #df = df[df.iloc[:, i] > 1.0]                
        print(len(df))
    return df

# %%
metall_concentration = full[[
'date', 
'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_au',
'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_au',         
'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_au'                     
                             ]]
metall_concentration['date'] = pd.to_datetime(metall_concentration['date'], format = '%Y-%m-%d %H:%M:%S')

# %% [markdown]
# Выбросим выбросы из нашего датафрейма metall_concentration используя функцию slice_preparation_wo_outliners. Затем построим графики без выьросов.

# %% [markdown]
# Применим функция для автоматического создания среза, на основании iqr. При этом, на экран будет выводиться длина среза после удаления выбросов из каждого из столбцов.

# %%
metall_concentration_wo_outliners = slice_preparation_wo_outliners(metall_concentration)
# Out:
# 22716
# 20664
# 20203
# 19991
# 19831
# 19567
# 19256
# 19123
# 19086
# 18828

# %%
metall_concentration_wo_outliners['date'] = pd.to_datetime(metall_concentration_wo_outliners['date'], format = '%Y-%m-%d %H:%M:%S')
metall_concentration_wo_outliners['date_rounded'] = metall_concentration_wo_outliners['date'].dt.round('1D')

metall_concentration_wo_outliners.dropna(subset = [
'date', 
'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag',
'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb', 
'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au'                     
                             ], 
                               inplace = True)
metall_concentration_grouped = metall_concentration_wo_outliners.groupby('date_rounded')[[
'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag',
'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb', 
'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au']].mean()
print(f"Кол-во записей после группировки по date_rounded, равный 1 день: {(len(metall_concentration_grouped))}")
# Out:
# Кол-во записей после группировки по date_rounded, равный 1 день: 881

# %%
draw_timeline(metall_concentration_grouped, 'au')

# %%
draw_timeline(metall_concentration_grouped, 'pb')

# %%
draw_timeline(metall_concentration_grouped, 'ag')

# %% [markdown]
# ### Вывод.

# %% [markdown]
# ## Сравнение распределений размеров гранул сырья на обучающей и тестовой выборках.

# %% [markdown]
# По сути нам, нужно посмотреть статистики по столбцу rougher.input.feed_size в обучающей и тестовых выборках.

# %%
f, axes = plt.subplots(1, 1, figsize=(20, 9))
axes.set_title('Плотность распредления гранул сырья', fontsize=18)
axes.set_ylabel('Плотность появления значений', fontsize=15)
axes.set_xlabel('Размер гранул сырья', fontsize=15)
sns.distplot(train['rougher.input.feed_size'], bins=30)
sns.distplot(test['rougher.input.feed_size'], bins=30)
# Out:
# <AxesSubplot:title={'center':'Плотность распредления гранул сырья'}, xlabel='rougher.input.feed_size', ylabel='Плотность появления значений'>

# %% [markdown]
# Определим интервалы выбросов по каждому из столбцов.

# %%
iqr(train, 'rougher.input.feed_size')
# Out:
# Нижняя граница: 20.776369220802977
# Верхняя граница: 92.16977744528266

# %%
iqr(test, 'rougher.input.feed_size')
# Out:
# Нижняя граница: 17.269477433776323
# Верхняя граница: 88.25980869127523

# %% [markdown]
# Сделаем срезы согласно границам выбросов.

# %%
f, axes = plt.subplots(1, 1, figsize=(20, 9))
axes.set_title('Плотность распредления гранул сырья', fontsize=18)
axes.set_ylabel('Плотность появления значений', fontsize=15)
axes.set_xlabel('Размер гранул сырья', fontsize=15)
sns.distplot(train[(train['rougher.input.feed_size'] > 21.77) & (train['rougher.input.feed_size'] < 90.20)]['rougher.input.feed_size'], bins=30)
sns.distplot(test[(test['rougher.input.feed_size'] > 18.26) & (test['rougher.input.feed_size'] < 87.30)]['rougher.input.feed_size'], bins=30)
# Out:
# <AxesSubplot:title={'center':'Плотность распредления гранул сырья'}, xlabel='rougher.input.feed_size', ylabel='Плотность появления значений'>

# %% [markdown]
# ### Вывод.

# %% [markdown]
# Исходя из графкиов распределний, можно сделать вывод, что плотности гранул сырья совпадают в обоих выборках. Для более детального анализа, можно вывести нулевую гипотезу и проверить ее на статистическую значимость.

# %% [markdown]
# ## Исследование суммарных концентраций веществ.

# %% [markdown]
# Выделим суммы по каждому из веществ.

# %%
metall_concentration_grouped['rougher_sum'] = metall_concentration_grouped['rougher.output.concentrate_ag'] + \
                                      metall_concentration_grouped['rougher.output.concentrate_au'] + \
                                      metall_concentration_grouped['rougher.output.concentrate_pb']
metall_concentration_grouped['primary_cleaner_sum'] = metall_concentration_grouped['primary_cleaner.output.concentrate_ag'] + \
                                      metall_concentration_grouped['primary_cleaner.output.concentrate_au'] + \
                                      metall_concentration_grouped['primary_cleaner.output.concentrate_pb']
metall_concentration_grouped['final_output_sum'] = metall_concentration_grouped['final.output.concentrate_ag'] + \
                                      metall_concentration_grouped['final.output.concentrate_au'] + \
                                      metall_concentration_grouped['final.output.concentrate_pb']
list(metall_concentration.columns);

# %%
def draw_timeline_sum(df, element_of_the_column_name):
    """
    This function draws 2 graphs:
    1) Metall concentrations vs time for 3 different technological process
    2) Metall concentrations vs technological operation
    
    Input parameters:
    df - dataframe
    element_of_the_periodic_table - chemical element according to Periodic table. Abbreviation according to the table. 
    # !!!element_of_the_periodic_table sum!!! i.e. summ 
    """
    dict_sample = dict({'sum': 'Сумма'})
    
    column_names = []
    
    for column in metall_concentration_grouped.columns:
        if column.find(element_of_the_column_name) != -1:
            column_names.append(column)
    
    sns.set()
    f, axes = plt.subplots(1, 1, figsize=(20, 9))
    axes.set_title(dict_sample[element_of_the_column_name] + ' по всем металлам распределений концентрациии по времени по трем технолог. процессам', fontsize=18)
    axes.set_ylabel('Концентрация', fontsize=15)
    axes.set_xlabel('Распределение по дням', fontsize=15)
    sns.lineplot(data = df[column_names])
    
    sns.set()
    f, axes = plt.subplots(1, 1, figsize=(20, 9))
    axes.set_title(' Медианы и распредления суммы концентраций по металлам по трем технолог. процессам', fontsize=18)
    axes.set_ylabel('Медианы по технологическим операциям', fontsize=15)
    axes.set_xlabel('Технологические операции', fontsize=15)
    ax = sns.violinplot(data = df[column_names])

# %%
draw_timeline_sum(metall_concentration_grouped, 'sum')

# %%
print(f"Кол-во записей после удаления выбросов: {(len(metall_concentration_wo_outliners))}")
# Out:
# Кол-во записей после удаления выбросов: 18828

# %% [markdown]
# ### Вывод.

# %% [markdown]
# Таким образом, мы проверили суммарные концентрации веществ на каждом из этапов. Суммарные концентрации увеличиваются в течение технологического процесса.
# Для более детального анализа необходимо углубиться в технологию производства.
# **Так же, мы получили срез данных, содержащий 17508 строк, по индексам которых мы будем срезать наши данные в обучающей и тестовой выборках.**

# %% [markdown]
# # Финальная подготовка данных для построения моделей.

# %% [markdown]
# ## Подготовка выборок.

# %% [markdown]
# Проведем следующие операции:
# 1) В файле metall_concentration_wo_outliners выстовим в качетсве индексов дату (столбец date).

# %%
metall_concentration_wo_outliners = metall_concentration_wo_outliners.set_index('date')

# %% [markdown]
# 2) Выборки train, test, full заполним методом fillna с аргументом ffill.
# 3) Переведем столбец date в датафреймах train, test, full в формат даты и времени.
# 3) Установим индексы дату (столбец date).
# 4) Дропним столбцы в train, которых нет в test.
# 5) Сматчим элементы датафреймов по индексам таблицы metall_concentration_wo_outliners

# %%
train = train.fillna(method='ffill')
test = test.fillna(method='ffill')
full = full.fillna(method='ffill')

train['date'] = pd.to_datetime(full['date'], format = '%Y-%m-%d %H:%M:%S')
test['date'] = pd.to_datetime(test['date'], format = '%Y-%m-%d %H:%M:%S')
full['date'] = pd.to_datetime(full['date'], format = '%Y-%m-%d %H:%M:%S')

train = train.set_index('date')
test = test.set_index('date')
full = full.set_index('date')

train = train.drop([column for column in list(train.columns) if (column not in list(test.columns))], axis = 1)

train_wo_outliners = train.loc[train.index.intersection(metall_concentration_wo_outliners.index)]
test_wo_outliners = test.loc[test.index.intersection(metall_concentration_wo_outliners.index)]

print(f"Кол-во записей в train: {len(train_wo_outliners)}")
print(f"Кол-во записей в test: {len(test_wo_outliners)}")
# Out:
# Кол-во записей в train: 14291
# Кол-во записей в test: 5051

# %% [markdown]
# 6) Выделим из датафрейма full наши целевые признаки 'rougher.output.recovery', 'final.output.recovery' для выборки train

# %%
train_rougher_output_recovery_target = full['rougher.output.recovery'].loc[full.index.intersection(train_wo_outliners.index)]
train_final_output_recovery_target = full['final.output.recovery'].loc[full.index.intersection(train_wo_outliners.index)]
print(f"Кол-во записей в train_target: {len(train_rougher_output_recovery_target)}")
print(f"Кол-во записей в train_target: {len(train_final_output_recovery_target)}")
# Out:
# Кол-во записей в train_target: 14291
# Кол-во записей в train_target: 14291

# %% [markdown]
# 7) Выделим из датафрейма full наши целевые признаки 'rougher.output.recovery', 'final.output.recovery' для выборки test

# %%
test_rougher_output_recovery_target = full['rougher.output.recovery'].loc[full.index.intersection(test_wo_outliners.index)]
test_final_output_recovery_target = full['final.output.recovery'].loc[full.index.intersection(test_wo_outliners.index)]
print(f"Кол-во записей в test_target: {len(test_rougher_output_recovery_target)}")
print(f"Кол-во записей в test_target: {len(test_final_output_recovery_target)}")
# Out:
# Кол-во записей в test_target: 5051
# Кол-во записей в test_target: 5051

# %% [markdown]
# **Нашей задачей является вычисление 2 целевых признаков. Один из которых является rougher.output.recovery - показетль эффективности технологического процесса флотация. Второй final.output.recovery - показатель эффективности обагащения финального концентрата. Поэтому, считаем необходимым, наши features разделить на 2 категории:**
# *1) Features для расчета первого целевого призанака rougher.output.recovery. В данные features будут входить столбцы с "приставкой" rougher.*
# *2) Features для расчета второго целевого призанака final.output.recovery. В данные features будут входить столбцы с "приставкой" primary_cleaner, secondary_cleaner.*

# %%
train_wo_outliners_for_target_one = train_wo_outliners[['rougher.input.feed_ag',
       'rougher.input.feed_pb', 'rougher.input.feed_rate',
       'rougher.input.feed_size', 'rougher.input.feed_sol',
       'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
       'rougher.input.floatbank10_xanthate',
       'rougher.input.floatbank11_sulfate',
       'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
       'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
       'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
       'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
       'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
       'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
       'rougher.state.floatbank10_f_level',]]

train_wo_outliners_for_target_two = train_wo_outliners[['primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
       'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
       'primary_cleaner.state.floatbank8_a_air',
       'primary_cleaner.state.floatbank8_a_level',
       'primary_cleaner.state.floatbank8_b_air',
       'primary_cleaner.state.floatbank8_b_level',
       'primary_cleaner.state.floatbank8_c_air',
       'primary_cleaner.state.floatbank8_c_level',
       'primary_cleaner.state.floatbank8_d_air',
       'primary_cleaner.state.floatbank8_d_level',
       'secondary_cleaner.state.floatbank2_a_air',
       'secondary_cleaner.state.floatbank2_a_level',
       'secondary_cleaner.state.floatbank2_b_air',
       'secondary_cleaner.state.floatbank2_b_level',
       'secondary_cleaner.state.floatbank3_a_air',
       'secondary_cleaner.state.floatbank3_a_level',
       'secondary_cleaner.state.floatbank3_b_air',
       'secondary_cleaner.state.floatbank3_b_level',
       'secondary_cleaner.state.floatbank4_a_air',
       'secondary_cleaner.state.floatbank4_a_level',
       'secondary_cleaner.state.floatbank4_b_air',
       'secondary_cleaner.state.floatbank4_b_level',
       'secondary_cleaner.state.floatbank5_a_air',
       'secondary_cleaner.state.floatbank5_a_level',
       'secondary_cleaner.state.floatbank5_b_air',
       'secondary_cleaner.state.floatbank5_b_level',
       'secondary_cleaner.state.floatbank6_a_air',
       'secondary_cleaner.state.floatbank6_a_level']]

test_wo_outliners_for_target_one = test_wo_outliners[['rougher.input.feed_ag',
       'rougher.input.feed_pb', 'rougher.input.feed_rate',
       'rougher.input.feed_size', 'rougher.input.feed_sol',
       'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
       'rougher.input.floatbank10_xanthate',
       'rougher.input.floatbank11_sulfate',
       'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
       'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
       'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
       'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
       'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
       'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
       'rougher.state.floatbank10_f_level',]]

test_wo_outliners_for_target_two = test_wo_outliners[['primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
       'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
       'primary_cleaner.state.floatbank8_a_air',
       'primary_cleaner.state.floatbank8_a_level',
       'primary_cleaner.state.floatbank8_b_air',
       'primary_cleaner.state.floatbank8_b_level',
       'primary_cleaner.state.floatbank8_c_air',
       'primary_cleaner.state.floatbank8_c_level',
       'primary_cleaner.state.floatbank8_d_air',
       'primary_cleaner.state.floatbank8_d_level',
       'secondary_cleaner.state.floatbank2_a_air',
       'secondary_cleaner.state.floatbank2_a_level',
       'secondary_cleaner.state.floatbank2_b_air',
       'secondary_cleaner.state.floatbank2_b_level',
       'secondary_cleaner.state.floatbank3_a_air',
       'secondary_cleaner.state.floatbank3_a_level',
       'secondary_cleaner.state.floatbank3_b_air',
       'secondary_cleaner.state.floatbank3_b_level',
       'secondary_cleaner.state.floatbank4_a_air',
       'secondary_cleaner.state.floatbank4_a_level',
       'secondary_cleaner.state.floatbank4_b_air',
       'secondary_cleaner.state.floatbank4_b_level',
       'secondary_cleaner.state.floatbank5_a_air',
       'secondary_cleaner.state.floatbank5_a_level',
       'secondary_cleaner.state.floatbank5_b_air',
       'secondary_cleaner.state.floatbank5_b_level',
       'secondary_cleaner.state.floatbank6_a_air',
       'secondary_cleaner.state.floatbank6_a_level']]

# %% [markdown]
# ### Вывод.

# %% [markdown]
# Таким образом получили следующие датафреймы, **которые будет использоваться в моделировании:**
#
#
# **1) train_wo_outliners_for_target_one - обучающая выборка для первого целевого признака. 14291 записей / 22 столбца**
# **2) train_wo_outliners_for_target_two - обучающая выборка для второго целевого признака. 14291 записей / 30 столбцов**
# **3) test_wo_outliners_for_target_one - тестовая выборка для первого целевого признака. 5051 записи / 22 столбца**
# **4) test_wo_outliners_for_target_two - тестовая выборка для второго целевого признака. 5051 записи / 30 столбцов**
# **5) train_rougher_output_recovery_target - первый целевой признак для обучения. 14291 записей / 1 столбец**
# **6) train_final_output_recovery_target - второй целевой признак для обучения. 14291 записей / 1 столбец**
# **7) test_rougher_output_recovery_target - первый целевой признак для теста. 5051 записи / 1 столбец**
# **8) test_final_output_recovery_target - второй целевой признак для теста. 5051 записи / 1 столбец**

# %% [markdown]
# ## Функция для вычесления итоговой sMAPE.

# %% [markdown]
# Напишем функцию sMAPE по которой будем считать эффективность моделей.

# %%
def sMAPE(target, prediction):
    """
    Function for smape calculation.
    
    Input parameters:
    target - our target
    prediction - our prediction
    
    Output parameteres:
    sMAPE in percentages
    """
    return np.sum(np.abs(target - prediction)/((np.abs(target) + np.abs(prediction)) / 2)) * 100/len(target)

# %%
def final_sMAPE(floatt, final):
    """
    Fuction calculates final_sMAPE, based on targets and predictions for both targets (target 1 (rougher process), 
    target 2 (primary cleaning))
    Input parameters:
    float - sMAPE for rougher process
    final - sMPAE for primapry cleaning
    Output parameters:
    final_sMAPE - sMAPE for the whole technological chain
    """
    final_sMAPE = 0
    final_sMAPE = 0.25 * floatt + 0.75 * final
    return final_sMAPE

# %% [markdown]
# # Моделирование. Получение результатов.

# %% [markdown]
# В качестве моделей будем использовать:
# 1) Линейная регрессия - LinearRegression (будет бейзлайном)
# 2) Дерево решений в регрессии - DecisionTreeRegressor
# 3) Случайный лес в регрессии - RandomForestRegressor
# 4) Elastic Net

# %% [markdown]
# ## Бейзлайн на константной модели.

# %%
dummy_regr_1 = DummyRegressor(strategy='mean')
dummy_regr_1.fit(train_wo_outliners_for_target_one, train_rougher_output_recovery_target)
prediction_1 = dummy_regr_1.predict(train_wo_outliners_for_target_one)

dummy_regr_2 = DummyRegressor(strategy='mean')
dummy_regr_2.fit(train_wo_outliners_for_target_two, train_final_output_recovery_target)
prediction_2 = dummy_regr_1.predict(train_wo_outliners_for_target_two)

final_sMAPE_DR = final_sMAPE(sMAPE(train_rougher_output_recovery_target, prediction_1), 
            sMAPE(train_final_output_recovery_target, prediction_2))

print(f"Показатель sMAPE для бейзлайна константная модель: {final_sMAPE_DR}%")
# Out:
# Показатель sMAPE для бейзлайна константная модель: 19.53206063883914%

# %%
dummy_regr_1 = DummyRegressor(strategy='mean')
dummy_regr_1.fit(train_wo_outliners_for_target_one, train_rougher_output_recovery_target)
prediction_1 = dummy_regr_1.predict(test_wo_outliners_for_target_one)

dummy_regr_2 = DummyRegressor(strategy='mean')
dummy_regr_2.fit(train_wo_outliners_for_target_two, train_final_output_recovery_target)
prediction_2 = dummy_regr_2.predict(test_wo_outliners_for_target_one)

final_sMAPE_DR = final_sMAPE(sMAPE(test_rougher_output_recovery_target, prediction_1), 
            sMAPE(test_final_output_recovery_target, prediction_2))

print(f"Показатель sMAPE для бейзлайна константная модель: {final_sMAPE_DR}%")
# Out:
# Показатель sMAPE для бейзлайна константная модель: 7.918547773662537%

# %% [markdown]
# ## Нахождение лучшей модели по критерию sMAPE.

# %% [markdown]
# Создадим датафрейм, в которой подадим интересующие нас модели, параметры через словарь. Далее напишем функцию, котороя будет вытягивать из данного датафрейма модели, инициализировать их, и искать лучшие параметры через GridSerchCV. Далее на тесте высчитывать предсказание и подставлять в функцию SMAPE

# %%
data_models = [
    
['Линейная Регрессия', 'sklearn.linear_model', 'LinearRegression', {}],
    
['Дерево решений в регрессии', 'sklearn.tree', 'DecisionTreeRegressor', 
{'max_depth': range(1, 10, 1), 'random_state': [12345], 'min_samples_leaf': range(2, 6), 'min_samples_split': range(2, 6)}],

['Случайный лес в регрессии','sklearn.ensemble', 'RandomForestRegressor', 
{'n_estimators': range(1, 5, 1), 'max_depth': range(1, 5, 1), 'random_state': [12345], 'min_samples_leaf': range(2, 6), 
             'min_samples_split': range(2, 6)}], 
    
['Модель Elastic Net','sklearn.linear_model', 'ElasticNet', 
{'l1_ratio': np.linspace(0, 1, 15, endpoint=True), 'alpha': np.linspace(0.1, 1, 10, endpoint=True), 'random_state': [12345]}]
    
              ] 
   
models_df = pd.DataFrame(data_models, columns = ['label','module','model', 'parameters'])
display(models_df)
# Out:
#                         label                module                  model  \
# 0          Линейная Регрессия  sklearn.linear_model       LinearRegression
# 1  Дерево решений в регрессии          sklearn.tree  DecisionTreeRegressor
# 2   Случайный лес в регрессии      sklearn.ensemble  RandomForestRegressor
# 3          Модель Elastic Net  sklearn.linear_model             ElasticNet
#
#                                                                                                                                                                                                                                                                                                                                                                                                parameters
# ...

# %%
def grid_model_test_output(param_table, slice_fea_train_1, slice_tar_train_1, slice_fea_train_2, slice_tar_train_2):
    """
    Function for the best model definition based on our task's score sMAPE. The function returns a table with all models which
    user wants to check. The table contatins information on sMAPE, sMAPE delta vs constant model (dummy Regression), best model 
    parameters and best model (already fitted)
    
    Entry parameters:
    param_table - df with all necessary models and model parameters, listed through vocabulary
    slice_fea_train_1 - features train for target 1
    slice_tar_train_1 - train target 1
    slice_fea_train_2 - features train for target 2
    slice_tar_train_2 - train target 2
    
    Output parameters:
    result_df - dataframe with models info after GridSearchCV operation
    best_model_for_target_1 - best model, based on sMAPE, for target 1. Already fitted
    best_model_for_target_2 - best model, based on sMAPE, for target 2. Already fitted
    """
    the_best_score_result = final_sMAPE_DR
    result_df = []
    for index, row in param_table.iterrows():
        
        module_imported = importlib.import_module(row['module'])
        model_imported = getattr(module_imported, row['model'])
        model = model_imported()
        if verbose:
            print(model)
            
        grid_1 = GridSearchCV(model, row['parameters'], scoring = make_scorer(sMAPE, greater_is_better = False), 
                            cv = 5, verbose = 1, n_jobs = -1).fit(slice_fea_train_1, slice_tar_train_1)
        smape_rougher = sMAPE(test_rougher_output_recovery_target, 
                              grid_1.best_estimator_.predict(test_wo_outliners_for_target_one))
        
        grid_2 = GridSearchCV(model, row['parameters'], scoring = make_scorer(sMAPE, greater_is_better = False),
                             cv = 5, verbose =1, n_jobs = -1).fit(slice_fea_train_2, slice_tar_train_2)
        smape_clean = sMAPE(test_final_output_recovery_target, 
                              grid_2.best_estimator_.predict(test_wo_outliners_for_target_two))     
        
    
        
        final_sMAPE_result = final_sMAPE(smape_rougher, smape_clean)
        delta_vs_baseline = final_sMAPE_DR - final_sMAPE_result
        
        if final_sMAPE_result < the_best_score_result:
            the_best_score_result = final_sMAPE_result
            best_model_for_target_1 = grid_1.best_estimator_
            best_model_for_target_2 = grid_2.best_estimator_

             
        result_df.append([smape_rougher, smape_clean, final_sMAPE_result, row['label'], grid_1.best_params_, grid_2.best_params_, delta_vs_baseline])
        
    result_df = pd.DataFrame(result_df, columns = ['smape_rougher', 'smape_clean', 'Final sMAPE', 'Название модели', 'Оптимальные параметры_модель_1',
                                                  'Оптимальные параметры_модель_2', 'Дельта с константной моделью']) 
    
    result_df = result_df.sort_values(by = 'Final sMAPE', ascending = True)
    return result_df, best_model_for_target_1, best_model_for_target_2

# %%
# %%time
result_df, best_model_for_target_1, best_model_for_target_2 = grid_model_test_output(models_df, 
                                                      train_wo_outliners_for_target_one, train_rougher_output_recovery_target, 
                                                      train_wo_outliners_for_target_two, train_final_output_recovery_target)
display(result_df)
# Out:
# LinearRegression()
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# DecisionTreeRegressor()
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# RandomForestRegressor()
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# ElasticNet()
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
#    smape_rougher  smape_clean  Final sMAPE             Название модели  \
# 3           6.37         8.32         7.83          Модель Elastic Net
# 0           6.33         8.63         8.06          Линейная Регрессия
# 2           7.06         9.57         8.94   Случайный лес в регрессии
# 1           7.01         9.60         8.95  Дерево решений в регрессии
#
# ...

# %%
print(best_model_for_target_1)
print(best_model_for_target_2)
# Out:
# ElasticNet(l1_ratio=1.0, random_state=12345)
# ElasticNet(l1_ratio=1.0, random_state=12345)

# %% [markdown]
# ### Вывод.

# %% [markdown]
# **Таким образом получили обученные модели для 2 целевых признаков. Лучшими моделями являются:**

# %%
print(best_model_for_target_1)
print(best_model_for_target_2)
# Out:
# ElasticNet(l1_ratio=1.0, random_state=12345)
# ElasticNet(l1_ratio=1.0, random_state=12345)

# %% [markdown]
# ## Расчет на тестовой выборке

# %%
test_prediction_1 = best_model_for_target_1.predict(test_wo_outliners_for_target_one)


test_prediction_2 = best_model_for_target_2.predict(test_wo_outliners_for_target_two)

final_sMAPE_test = final_sMAPE(sMAPE(test_rougher_output_recovery_target, test_prediction_1), 
            sMAPE(test_final_output_recovery_target, test_prediction_2))

print(f"Показатель sMAPE для тестовых данных: {final_sMAPE_test}%")
# Out:
# Показатель sMAPE для тестовых данных: 7.831752967883685%

# %% [markdown]
# # Вывод

# %% [markdown]
# **Таким образом, лучшая модель: ElasticNet().
# Показатель итогового sMAPE на тестовых данных: 7.831752967883685%**
